# %%
import pandas as pd
# Lecture du fichier CSV
import_data = pd.read_csv('C:\\Users\\hp\\Desktop\\ACP\\cancer patient data sets.csv')

# %%
# les noms des colonnes du DataFrame import_data :
import_data.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
# Vérification des valeurs manquantes par colonne
missing_values = import_data.isnull().sum()
print("Valeurs manquantes par colonne :\n", missing_values)
# Out:
# Valeurs manquantes par colonne :
#  index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
import_data
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy
# 0        0         P1   33       1              2            4             5  \
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
# Supprimer les colonnes "Patient Id" , "Level" ,"index" et "Gender"
data = import_data.drop(columns=['Patient Id', 'Level','index','Gender'])

# %%
data
# Out:
#      Age  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards
# 0     33              2            4             5                     4  \
# 1     17              3            1             5                     3
# 2     35              4            5             6                     5
# 3     37              7            7             7                     7
# 4     46              6            8             7                     7
# ..   ...            ...          ...           ...                   ...
# 995   44              6            7             7                     7
# 996   37              6            8             7                     7
# 997   25              4            5             6                     5
# 998   18              6            8             7                     7
# 999   47              6            5             6                     5
#
#      Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  ...
# ...

# %%
# Informations générales sur les données
print("Nombre de lignes et de colonnes :", data.shape)
print("Aperçu des premières lignes :\n", data.head())
# Out:
# Nombre de lignes et de colonnes : (1000, 22)
# Aperçu des premières lignes :
#     Age  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards
# 0   33              2            4             5                     4  \
# 1   17              3            1             5                     3
# 2   35              4            5             6                     5
# 3   37              7            7             7                     7
# 4   46              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  ...
# 0             3                     2              2        4        3  ...  \
# 1             4                     2              2        2        2  ...
# 2             5                     4              6        7        2  ...
# 3             6                     7              7        7        7  ...
# 4             7                     6              7        7        8  ...
#
# ...

# %%
print("Résumé statistique des variables numériques :\n", data.describe())
# Out:
# Résumé statistique des variables numériques :
#                 Age  Air Pollution  Alcohol use  Dust Allergy
# count  1000.000000      1000.0000  1000.000000   1000.000000  \
# mean     37.174000         3.8400     4.563000      5.165000
# std      12.005493         2.0304     2.620477      1.980833
# min      14.000000         1.0000     1.000000      1.000000
# 25%      27.750000         2.0000     2.000000      4.000000
# 50%      36.000000         3.0000     5.000000      6.000000
# 75%      45.000000         6.0000     7.000000      7.000000
# max      73.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease
# count           1000.000000   1000.000000           1000.000000  \
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# min                1.000000      1.000000              1.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Création d'une instance de la classe StandardScaler
scaler = StandardScaler()
# La classe StandardScaler est utilisée pour effectuer une mise à l'échelle standard sur les données.
# Cela implique de centrer les données autour de zéro et de les mettre à la même échelle en ajustant
# la moyenne et l'écart type de chaque variable.
# Cette étape est souvent utiliséepour normaliser les données avant de les utiliser dans un modèle d'apprentissage automatique.

# Utilisation de la méthode fit_transform() pour effectuer une mise à l'échelle standard
matrice_centree_reduite = scaler.fit_transform(data)
matrice_centree_reduite
# Out:
# array([[-0.34784816, -0.90667901, -0.21495391, ..., -0.83861787,
#         -0.41855027,  0.72865507],
#        [-1.68123833, -0.41391868, -1.36035665, ..., -1.38459305,
#          1.54417079, -0.6282445 ],
#        [-0.18117439,  0.07884165,  0.166847  , ...,  1.34528283,
#          1.54417079, -0.6282445 ],
#        ...,
#        [-1.01454325,  0.07884165,  0.166847  , ...,  1.34528283,
#          1.54417079, -0.6282445 ],
#        [-1.59790145,  1.06436231,  1.31224973, ...,  0.25333248,
#         -0.90923053,  0.05020528],
#        [ 0.81886824,  1.06436231,  0.166847  , ...,  1.34528283,
#          1.54417079, -0.6282445 ]])

# %%
import numpy as np
# Utilisation de la fonction np.corrcoef() pour calculer la matrice de corrélation
matrice_correlation = np.corrcoef(matrice_centree_reduite, rowvar=False)
matrice_correlation
# Out:
# array([[ 1.        ,  0.09949419,  0.15174172,  0.0352017 ,  0.06217738,
#          0.07315054,  0.12895164,  0.0048635 ,  0.03433716,  0.07533258,
#          0.00490762,  0.01286355,  0.0530064 ,  0.09505877,  0.1069457 ,
#          0.03532928, -0.09535409, -0.10583269,  0.0392583 , -0.01270648,
#          0.0121276 , -0.00469982],
#        [ 0.09949419,  1.        ,  0.74729261,  0.6375035 ,  0.60892446,
#          0.70527606,  0.62670091,  0.52487291,  0.6014675 ,  0.48190161,
#          0.6067637 ,  0.58573351,  0.6078286 ,  0.2117239 ,  0.25801612,
#          0.26955773,  0.05536764, -0.08091767,  0.24106478,  0.17453909,
#          0.26148864, -0.02134255],
#        [ 0.15174172,  0.74729261,  1.        ,  0.81864352,  0.87878592,
#          0.87720989,  0.76357577,  0.65335189,  0.66931156,  0.54703463,
#          0.59257638,  0.71724228,  0.66761184,  0.23724513,  0.20785108,
#          0.43578528,  0.18081698, -0.11407317,  0.41499215,  0.18077782,
# ...

# %%
# Utilisation de la fonction np.linalg.eig() pour calculer les valeurs propres et les vecteurs propres
valeurs_propres, vecteurs_propres= np.linalg.eig(matrice_correlation)
valeurs_propres
# Out:
# array([9.04470738, 2.69826278, 2.01529071, 1.51603062, 1.26088442,
#        1.04461727, 0.69223316, 0.60531808, 0.54175786, 0.49956438,
#        0.42880318, 0.34311455, 0.28369437, 0.23047792, 0.20978102,
#        0.15982925, 0.02399732, 0.03329486, 0.11793661, 0.06875057,
#        0.09730202, 0.08435168])

# %%
# Calcul de l'inertie totale
inertie_totale = np.sum(valeurs_propres)
inertie_expliquee = (valeurs_propres / inertie_totale)
inertie_expliquee
# Out:
# array([0.41112306, 0.12264831, 0.09160412, 0.06891048, 0.05731293,
#        0.0474826 , 0.03146514, 0.02751446, 0.02462536, 0.02270747,
#        0.01949105, 0.01559612, 0.0128952 , 0.01047627, 0.0095355 ,
#        0.00726497, 0.00109079, 0.0015134 , 0.00536075, 0.00312503,
#        0.00442282, 0.00383417])

# %%
# Utilisation de la fonction np.dot() pour calculer les composantes principales
composantes_principales = np.dot(matrice_centree_reduite, vecteurs_propres)
composantes_principales
# Out:
# array([[ 2.61262186, -0.64809496,  0.01366454, ..., -0.05828683,
#          0.69420613, -0.20263739],
#        [ 2.57659831,  1.081703  ,  0.45073504, ...,  0.47583134,
#         -0.66094997,  0.16796698],
#        [-1.65376825,  2.89236999,  0.4137381 , ...,  0.02095766,
#          0.00358898, -0.07052301],
#        ...,
#        [-1.63020062,  2.8720405 ,  0.50809305, ...,  0.00678056,
#          0.01338717, -0.08128316],
#        [-3.47528487, -2.63016801, -0.2773877 , ..., -0.06499443,
#         -0.07287622,  0.01302988],
#        [-1.93192634,  2.91213484,  0.18074308, ...,  0.06174343,
#          0.07680921,  0.34195727]])

# %%
import pandas as pd

vecteurs_pondere =-1* vecteurs_propres * np.sqrt(valeurs_propres)

data_frame = pd.DataFrame(vecteurs_pondere)
data_frame
# Out:
#           0         1         2         3         4         5         6
# 0   0.085050 -0.040071  0.160730 -0.203747  0.172461 -0.894836 -0.145907  \
# 1   0.762531  0.007718  0.172523 -0.065959 -0.009907 -0.049064 -0.257911
# 2   0.896701 -0.035934  0.225564  0.022154 -0.178668 -0.110493  0.083273
# 3   0.851772 -0.186486  0.085032  0.113078 -0.044716  0.067382  0.066036
# 4   0.891380  0.027844  0.242373  0.123837 -0.098589  0.006839  0.149639
# 5   0.910594 -0.013343  0.286641  0.113229 -0.049458  0.026773  0.005272
# 6   0.820818  0.181744  0.239718  0.074864 -0.102221 -0.121215  0.065344
# 7   0.833646  0.186923 -0.148619 -0.191665 -0.025684  0.153524 -0.030666
# 8   0.853496 -0.010844 -0.118520 -0.059176  0.284129  0.089886  0.054138
# 9   0.643244  0.536731 -0.129982 -0.004519 -0.069574 -0.095689 -0.214997
# 10  0.763741  0.357916 -0.291087  0.150779  0.071901 -0.022488 -0.163557
# 11  0.850666  0.298359  0.057758  0.027724 -0.062721  0.078582  0.065966
# ...

# %%
import matplotlib.pyplot as plt
# Tracer les vecteurs pondérés
plt.figure(figsize=(8, 8))
plt.scatter(vecteurs_pondere[:, 0], vecteurs_pondere[:, 1])

# Ajouter un cercle de rayon 1
cercle = plt.Circle((0, 0), 1, edgecolor='black', facecolor='none', linestyle='--', linewidth=2)
plt.gca().add_patch(cercle)

for i, (x, y) in enumerate(zip(vecteurs_pondere[:, 0], vecteurs_pondere[:, 1])):
    # Calcul de l'inertie expliquée pour la composante principale actuelle
    inertie_exp = inertie_expliquee[i]

    # Ajouter le texte avec l'inertie de la composante principale
    plt.quiver(0, 0, x, y, angles='xy', scale_units='xy', scale=1, color='red', width=0.005,
             )

plt.axhline(0, color='black', linestyle='--', linewidth=0.5)
plt.axvline(0, color='black', linestyle='--', linewidth=0.5)
plt.title('Cercle de Corrélation avec Vecteurs Pondérés et Inertie')
plt.xlabel('Composante Principale 1')
plt.ylabel('Composante Principale 2')
plt.legend()  # Afficher la légende avec les labels
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.decomposition import PCA

# Calcul de la qualité
quality = np.square(vecteurs_propres) * valeurs_propres[:, np.newaxis]

# Calcul de la contribution
contribution = quality / np.sum(quality, axis=0)

# Affichage des résultats pour chaque variable
for i in range(len(data.columns)):
    print("Variable:", data.columns[i])
    print("Qualité:", quality[:, i])
    print("Contribution:", contribution[:, i])
    print("")
# Out:
# Variable: Age
# Qualité: [7.23355452e-03 1.73462316e-01 1.79159011e-01 1.21607359e-01
#  1.10765960e-01 9.57662094e-02 5.15646437e-02 4.65106552e-02
#  4.36328925e-02 2.28532925e-02 2.76538683e-02 2.74512818e-02
#  2.05102858e-02 5.50008140e-03 1.67588535e-03 3.94262575e-03
#  1.02773484e-04 1.84958389e-05 1.19589457e-03 5.48308091e-04
#  1.05151704e-03 1.33948694e-04]
# Contribution: [7.67615502e-03 1.84075978e-01 1.90121238e-01 1.29048166e-01
#  1.17543412e-01 1.01625870e-01 5.47197367e-02 4.93565091e-02
#  4.63026644e-02 2.42516201e-02 2.93459294e-02 2.91309472e-02
#  2.17652515e-02 5.83661565e-03 1.77842797e-03 4.18386374e-03
#  1.09061900e-04 1.96275464e-05 1.26906793e-03 5.81857495e-04
#  1.11585635e-03 1.42144631e-04]
#
# Variable: Air Pollution
# Qualité: [5.38236153e-03 5.95683080e-05 9.64397438e-04 1.95395835e-02
#  3.62298690e-04 6.89264010e-05 8.47397143e-03 7.83832416e-03
#  2.36109469e-05 5.33359566e-02 2.03580546e-02 1.13196684e-02
# ...
